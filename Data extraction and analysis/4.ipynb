# %%
#Задача 2
import pandas as pd
import numpy as np
data = pd.read_excel('dataframe.xlsx')
data
# Out:
#         ID                                   FullName   global_id  \
# 0    25330  Коворкинг «Рабочая станция» Парк Горького   861999679
# 1    25331        Коворкинг «Рабочая станция» ARTPLAY   861999681
# 2    25332             Коворкинг «Свободное плавание»   861999695
# 3    25333                         Коворкинг «Lerner»   861999696
# 4    25335           Коворкинг центр «Cabinet Lounge»   861999697
# ..     ...                                        ...         ...
# 159  88996                       WeWork Белая площадь  1015096030
# 160  88990                    WeWork Большая Якиманка  1015096034
# 161  89438              WeWork Ленинградский проспект  1015096069
# 162  88991                       WeWork Тимура Фрунзе  1015096070
# 163  88997                         Коворкинг Collider  1015096075
#
#                                      ShortName  \
# 0    Коворкинг «Рабочая станция» Парк Горького
# 1          Коворкинг «Рабочая станция» ARTPLAY
# ...

# %%
df = data.dropna(subset = ['Tariffs'])
df["Tariffs"] = df["Tariffs"].str.extract("(\d*\.?\d+)", expand=True)
df['Tariffs'].value_counts(normalize = True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1            0.168675
# 500.00       0.048193
# 200.00       0.036145
# 3            0.036145
# 300.00       0.036145
# 500          0.024096
# 3.00         0.024096
# 800.00       0.024096
# 100.00       0.024096
# 0.99         0.024096
# 0.00         0.024096
# 18           0.024096
# 900.00       0.024096
# 5500.00      0.012048
# 20000        0.012048
# 6000.00      0.012048
# 2500         0.012048
# 28000.00     0.012048
# 10900        0.012048
# 12000.00     0.012048
# 8            0.012048
# 150.00       0.012048
# 600.00       0.012048
# 350.00       0.012048
# 25000.00     0.012048
# 120000.00    0.012048
# ...

# %%
#Следовательно, доля бесплатных коворкингов указана в строке 0.00         0.024096, то есть равна 0,024096

# %%
df = data.dropna(subset = ['Tariffs'])
df["Tariffs"] = df["Tariffs"].str.extract("(\d*\.?\d+)", expand=True)
df['Tariffs'].value_counts()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1            14
# 500.00        4
# 200.00        3
# 3             3
# 300.00        3
# 500           2
# 3.00          2
# 800.00        2
# 100.00        2
# 0.99          2
# 0.00          2
# 18            2
# 900.00        2
# 5500.00       1
# 20000         1
# 6000.00       1
# 2500          1
# 28000.00      1
# 10900         1
# 12000.00      1
# 8             1
# 150.00        1
# 600.00        1
# 350.00        1
# 25000.00      1
# 120000.00     1
# 25000         1
# 10            1
# 1100          1
# 1200.00       1
# 49            1
# 60000.00      1
# 1000          1
# 5000.00       1
# 69            1
# ...

# %%
#Следовательно, количество бесплатных коворкингов указано в строке 0.00          2, а значит, число бесплатных равно двум.

# %%
#Задача 3
pd.to_numeric(df['Tariffs']).max()
# Out:
# 120000.0

# %%
#Задача 4
from bs4 import BeautifulSoup
import requests
import numpy as np

def extract(x):
    response = requests.get(x)
    soup = BeautifulSoup(response.text, 'html.parser')
    df['title_kov'] = soup.title
    

try:
    df["Site"].apply(extract)
except:
        df['title_kov'] = 'Cайт не ответил'
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
#Питон немного ругается, что в коде перезаписываются значения текущего датафрейма. Но, в целом, это нестрашно, так как при прогонке кода с начала запись в переменные начинается сначала.
