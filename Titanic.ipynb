# %%
import pandas as pd

# %%
pasInfo = pd.read_csv('titanic_data.csv')

# %%
pasInfo.head(10)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
# 5            6       3                                   Moran, Mr. James
# 6            7       1                            McCarthy, Mr. Timothy J
# 7            8       3                     Palsson, Master. Gosta Leonard
# 8            9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           10       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
pasInfo.tail(5)
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 886          887       2                     Montvila, Rev. Juozas    male
# 887          888       1              Graham, Miss. Margaret Edith  female
# 888          889       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890       1                     Behr, Mr. Karl Howell    male
# 890          891       3                       Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886  27.0      0      0      211536  13.00   NaN        S
# 887  19.0      0      0      112053  30.00   B42        S
# 888   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889  26.0      0      0      111369  30.00  C148        C
# 890  32.0      0      0      370376   7.75   NaN        Q

# %%
pasInfo.shape
# Out:
# (891, 11)

# %%
pasInfo.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pasInfo[['Age', 'Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
pasInfo[pasInfo['Embarked'] == 'S']
# Out:
#      PassengerId  Pclass                                          Name  \
# 0              1       3                       Braund, Mr. Owen Harris
# 2              3       3                        Heikkinen, Miss. Laina
# 3              4       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                      Allen, Mr. William Henry
# 6              7       1                       McCarthy, Mr. Timothy J
# ..           ...     ...                                           ...
# 883          884       2                 Banfield, Mr. Frederick James
# 884          885       3                        Sutehall, Mr. Henry Jr
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
pasInfo['Age'].mean()
# Out:
# 29.69911764705882

# %%
pasInfo['Age'].median()
# Out:
# 28.0

# %%
pasInfo['Fare'].sum()
# Out:
# 28693.9493

# %%
pasInfo.mean()
# Out:
# PassengerId    446.000000
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
pasInfo.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
pasInfo.Sex.value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
print(pasInfo.shape)
pasInfo.head(10)
# Out:
# (891, 11)
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
# 5            6       3                                   Moran, Mr. James
# 6            7       1                            McCarthy, Mr. Timothy J
# 7            8       3                     Palsson, Master. Gosta Leonard
# 8            9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           10       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
pasInfo.dropna()
# Out:
#      PassengerId  Pclass                                               Name  \
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6              7       1                            McCarthy, Mr. Timothy J
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
# 11            12       1                           Bonnell, Miss. Elizabeth
# ..           ...     ...                                                ...
# 871          872       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872          873       1                           Carlsson, Mr. Frans Olof
# 879          880       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887          888       1                       Graham, Miss. Margaret Edith
# 889          890       1                              Behr, Mr. Karl Howell
#
# ...

# %%
print(pasInfo.shape)
print(pasInfo.dropna().shape)
# Out:
# (891, 11)
# (183, 11)

# %%
pasInfo.dropna(axis = 0, subset = ['Cabin']).shape
# Out:
# (204, 11)

# %%
pasInfo.dropna(how='all').shape
# Out:
# (891, 11)

# %%
pasInfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# PassengerId    891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
pasInfo[pasInfo.Cabin.isnull()]['Pclass'].value_counts()
# Out:
# 3    479
# 2    168
# 1     40
# Name: Pclass, dtype: int64

# %%
pasInfo.fillna(-999).head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500  -999        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250  -999        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500  -999        S

# %% [markdown]
# Посчитайте, сколько пассажиров женщин было, а сколько мужчин

# %%
pasInfo['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# Какой самый молодой и самый старый пассажир на корабле?

# %%
pasInfo[pasInfo['Age'] == pasInfo['Age'].max()]
# Out:
#      PassengerId  Pclass                                  Name   Sex   Age  \
# 630          631       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 630      0      0  27042  30.0   A23        S

# %%
pasInfo[pasInfo['Age'] == pasInfo['Age'].min()]
# Out:
#      PassengerId  Pclass                             Name   Sex   Age  SibSp  \
# 803          804       3  Thomas, Master. Assad Alexander  male  0.42      0
#
#      Parch Ticket    Fare Cabin Embarked
# 803      1   2625  8.5167   NaN        C

# %% [markdown]
# Выведите датасет только с известным возрастом пассажиров

# %%
pasInfo.dropna(axis = 0, subset = ['Age'])
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 885          886       3               Rice, Mrs. William (Margaret Norton)
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Выведите датасет всех пассажиров, младше 6 лет. Сколько таких?

# %%
pasInfo[pasInfo['Age'] < 6].describe()
# Out:
#        PassengerId     Pclass        Age      SibSp      Parch        Fare
# count    44.000000  44.000000  44.000000  44.000000  44.000000   44.000000
# mean    410.954545   2.568182   2.503864   1.704545   1.363636   31.528030
# std     279.364391   0.624974   1.439669   1.503168   0.532258   29.434829
# min       8.000000   1.000000   0.420000   0.000000   0.000000    8.516700
# 25%     181.250000   2.000000   1.000000   1.000000   1.000000   18.237500
# 50%     378.500000   3.000000   2.000000   1.000000   1.000000   26.000000
# 75%     656.750000   3.000000   4.000000   3.000000   2.000000   31.387500
# max     870.000000   3.000000   5.000000   5.000000   2.000000  151.550000

# %%
pasInfo[pasInfo['Age'] < 6]

# %% [markdown]
# Выведите датасет только пассажиров женщин

# %%
pasInfo[pasInfo['Sex'] == 'female']
# Out:
#      PassengerId  Pclass                                               Name  \
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8              9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..           ...     ...                                                ...
# 880          881       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 882          883       3                       Dahlberg, Miss. Gerda Ulrika
# 885          886       3               Rice, Mrs. William (Margaret Norton)
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# Верно ли утверждение, что в каюте всегда останавливался один человек?

# %%
pasInfo[pasInfo.Cabin.isnull()]['Pclass'].value_counts() == 1
# Out:
# 3    False
# 2    False
# 1    False
# Name: Pclass, dtype: bool

# %%
df = pasInfo['Cabin'].value_counts() == 1
df[df == True]
# Out:
# A23        True
# C90        True
# E36        True
# D49        True
# D45        True
#            ...
# E17        True
# C101       True
# D15        True
# D10 D12    True
# A20        True
# Name: Cabin, Length: 101, dtype: bool

# %% [markdown]
# Загрузите датасет titanic_surv.csv и посчитайте количество и процент выживших

# %%
pasSurvival = pd.read_csv('titanic_surv.csv')

# %%
pasSurvival.Survived.value_counts(normalize = True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
pasSurvival.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
for group, groupDf in pasInfo.groupby('Pclass'):
    print(group, len(groupDf))
    #print(groupDf.describe())
# Out:
# 1 216
# 2 184
# 3 491

# %%
pasInfo.groupby(['Pclass']).mean()
# Out:
#         PassengerId        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  25.140620  0.615071  0.393075  13.675550

# %%
pasInfo[['Pclass', 'Age']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass        Age
# 0       1  38.233441
# 1       2  29.877630
# 2       3  25.140620

# %%
pasInfo.sort_values(by='Pclass', ascending=True).head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 445          446       1                          Dodge, Master. Washington
# 310          311       1                     Hays, Miss. Margaret Bechstein
# 309          310       1                     Francatelli, Miss. Laura Mabel
# 307          308       1  Penasco y Castellana, Mrs. Victor de Satode (M...
# 306          307       1                            Fleming, Miss. Margaret
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 445    male   4.0      0      2     33638   81.8583   A34        S
# 310  female  24.0      0      0     11767   83.1583   C54        C
# 309  female  30.0      0      0  PC 17485   56.9292   E36        C
# 307  female  17.0      1      0  PC 17758  108.9000   C65        C
# 306  female   NaN      0      0     17421  110.8833   NaN        C

# %%
pasInfo.join(pasSurvival).head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
pasInfo.merge(pasSurvival, right_index=True, left_index=True)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Посчитать долю выживших в каждом классе.

# %%
pasInfo.Sex.value_counts(normalize = True)

# %%
df = pasInfo.merge(pasSurvival, right_index=True, left_index=True)
df1 = df[['Survived', 'Pclass']].groupby(['Pclass'], as_index=False).mean()
df1
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
print("Верно ли, что женщины выживали чаще мужчин? Какие пассажиры выживали чаще: с более дешевыми или дорогими билетами? Верно ли, что чаще выживали более молодые пассажиры?")
# Out:
# Верно ли, что женщины выживали чаще мужчин? Какие пассажиры выживали чаще: с более дешевыми или дорогими билетами? Верно ли, что чаще выживали более молодые пассажиры?

# %%
df = pasInfo.merge(pasSurvival, right_index=True, left_index=True)
df1 = df[['Survived', 'Sex']].groupby(['Sex'], as_index=False).mean()
df1
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
pasInfo['Fare'].min(), pasInfo['Fare'].max(), pasInfo['Fare'].mean()
# Out:
# (0.0, 512.3292, 32.2042079685746)

# %%
df2 = pasInfo[pasInfo['Fare'] < 32]
df = df2.merge(pasSurvival, right_index=True, left_index=True)
df1 = df[['Survived', 'Fare']].groupby(['Fare'], as_index=False).mean()
df1['Survived'].mean()
#pasInfo.groupby(['Pclass']).mean()
#df
#df1 = df[['Survived', 'Fare']].groupby(['Fare'], as_index=False).count()
#df1
#df_new =df1.groupby('Survived').quantile(.95)
#df_new
#df1['Fare'].quantile(.5)
#df1.sort_values(by='Survived', ascending=False)
# Out:
# 0.3510933442905108

# %%
df2 = pasInfo[pasInfo['Fare'] > 32]
df = df2.merge(pasSurvival, right_index=True, left_index=True)
df1 = df[['Survived', 'Fare']].groupby(['Fare'], as_index=False).mean()
df1['Survived'].mean()
# Out:
# 0.6021915584415584

# %%
df2 = pasInfo[pasInfo['Age'] > 40]
df = df2.merge(pasSurvival, right_index=True, left_index=True)
df1 = df[['Survived', 'Age']].groupby(['Age'], as_index=False).mean()
df1['Survived'].mean()
# Out:
# 0.307353838971486

# %%
df2 = pasInfo[pasInfo['Age'] < 40]
df = df2.merge(pasSurvival, right_index=True, left_index=True)
df1 = df[['Survived', 'Age']].groupby(['Age'], as_index=False).mean()
df1['Survived'].mean()
# Out:
# 0.4464659422693972

# %%
print("Исследовать вопрос членов семьи. Сколько максимум/минимум на корабле? Как это повлияло на вероятность выжить?")
# Out:
# Исследовать вопрос членов семьи. Сколько максимум/минимум на корабле? Как это повлияло на вероятность выжить?

# %%
df['members'] = df.apply(lambda x: x['Parch'] + x['SibSp'], axis=1)
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df["members"].max()
# Out:
# 10

# %%
df = pasInfo.merge(pasSurvival, right_index=True, left_index=True)
df1 = df[['Survived', 'SibSp']].groupby(['SibSp'], as_index=False).mean()
df1
# Out:
#    SibSp  Survived
# 0      0  0.345395
# 1      1  0.535885
# 2      2  0.464286
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000
